# %%
ganancia_normal <- c(4369,3912,3833,4131,4438,4021,3882,4717,4359,5054,4528,4071,3942,4409,
                      4429,4021,4925,3982,4329,3892,3416,4299,4558,4280,4468)

ganancia_robusta <- c(3505,3654,4895,3644,4339,4071,3426,5104,4776,4558,4856,4309,4667,3664,
                     4290,3148,4200,4429,3952,3594,4299,4061,3406,4031,5144)

length(ganancia_normal)
length(ganancia_robusta)


cat("Ganancia normal",ganancia_normal,"\n")
cat("Ganancia robusta",ganancia_robusta)
# Out:
# [1] 25
# [1] 25
# Ganancia normal 4369 3912 3833 4131 4438 4021 3882 4717 4359 5054 4528 4071 3942 4409 4429 4021 4925 3982 4329 3892 3416 4299 4558 4280 4468
# Ganancia robusta 3505 3654 4895 3644 4339 4071 3426 5104 4776 4558 4856 4309 4667 3664 4290 3148 4200 4429 3952 3594 4299 4061 3406 4031 5144

# %%
# Prueba de que las distribuciones son distintas

wilcox.test(ganancia_robusta,
            ganancia_normal,
            paired = TRUE,
            alternative = "two.sided")
# Out:
# Warning message in wilcox.test.default(ganancia_robusta, ganancia_normal, paired = TRUE, :
# “cannot compute exact p-value with ties”
# 	Wilcoxon signed rank test with continuity correction
#
# data:  ganancia_robusta and ganancia_normal
# V = 133, p-value = 0.4352
# alternative hypothesis: true location shift is not equal to 0
