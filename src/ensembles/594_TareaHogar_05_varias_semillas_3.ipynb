# %% [markdown]
# <a href="https://colab.research.google.com/github/luciaphmaestria/labo2025v/blob/main/src/ensembles/594_TareaHogar_05_varias_semillas_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Drive already mounted at /content/.drive; to attempt to forcibly remount, call drive.mount("/content/.drive", force_remount=True).

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi
# Out:
# ln: failed to create symbolic link '/content/buckets/b1/labo1': File exists

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Nov 09 04:47:34 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used     (Mb)  gc trigger (Mb)  max used  (Mb)
# Ncells  2636495 140.9   4694445  250.8   4694445 250.8
# Vcells 17668371 134.8 107869491  823.0 112270698 856.6

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 5944
PARAM$semilla_primigenia <- 120539
PARAM$semilla_primigenia2 <- 230431

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5                          # Lu. Le pongo 0.5 porque sigue siendo muy desbalanceada la clase

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo    # Dejo que BO ajuste por num_leaves
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0                Lu. No voy a optimizar, dejo valor por defecto 1
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1, # scale_pos_weight > 0.0                         Lu. No voy a optimizar, dejo valor por defecto 1

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 2048,                                                # Lu. No voy a optimizar, dejo que se corte por early_stopping_rounds
  early_stopping_rounds=200,                                            # Lu. Si durante 200 iteraciones consecutivas la métrica AUC no mejora, el entrenamiento se detiene automáticamente.
  learning_rate= 0.03,                                                 #Lu. A optimizar. Cambie valor original 0.02
  feature_fraction= 0.5,                                               # Lu. No voy a optimizar, dejo fijo 0.5
  num_leaves= 512,                                                     #Lu. A optimizar. Cambie valor original 750
  min_data_in_leaf= 300                                               #Lu. A optimizar
)

# %%
print(PARAM)      #Lu
# Out:
# $experimento
# [1] 5944
#
# $semilla_primigenia
# [1] 120539
#
# $semilla_primigenia2
# [1] 230431
#
# $kaggle
# $kaggle$competencia
# [1] "labo-i-2025-virtual-analista-sr"
#
# $kaggle$cortes
# [1] 10000 10500 11000 11500 12000
#
#
# $trainingstrategy
# $trainingstrategy$undersampling
# [1] 0.5
#
#
# $hyperparametertuning
# $hyperparametertuning$xval_folds
# [1] 5
#
#
# $lgbm
# $lgbm$param_fijos
# $lgbm$param_fijos$boosting
# [1] "gbdt"
#
# $lgbm$param_fijos$objective
# [1] "binary"
#
# $lgbm$param_fijos$metric
# [1] "auc"
#
# $lgbm$param_fijos$first_metric_only
# [1] FALSE
#
# $lgbm$param_fijos$boost_from_average
# [1] TRUE
#
# $lgbm$param_fijos$feature_pre_filter
# [1] FALSE
#
# $lgbm$param_fijos$force_row_wise
# [1] TRUE
#
# $lgbm$param_fijos$verbosity
# [1] -100
#
# $lgbm$param_fijos$seed
# [1] 120539
#
# $lgbm$param_fijos$max_depth
# [1] -1
#
# $lgbm$param_fijos$min_gain_to_split
# [1] 0
#
# $lgbm$param_fijos$min_sum_hessian_in_leaf
# [1] 0.001
#
# $lgbm$param_fijos$lambda_l1
# [1] 0
#
# $lgbm$param_fijos$lambda_l2
# [1] 0
#
# $lgbm$param_fijos$max_bin
# [1] 31
#
# $lgbm$param_fijos$bagging_fraction
# [1] 1
#
# $lgbm$param_fijos$pos_bagging_fraction
# [1] 1
#
# $lgbm$param_fijos$neg_bagging_fraction
# [1] 1
#
# $lgbm$param_fijos$is_unbalance
# [1] FALSE
#
# $lgbm$param_fijos$scale_pos_weight
# [1] 1
#
# $lgbm$param_fijos$drop_rate
# [1] 0.1
#
# $lgbm$param_fijos$max_drop
# [1] 50
#
# $lgbm$param_fijos$skip_drop
# [1] 0.5
#
# $lgbm$param_fijos$extra_trees
# [1] FALSE
#
# $lgbm$param_fijos$num_iterations
# [1] 2048
#
# $lgbm$param_fijos$early_stopping_rounds
# [1] 200
#
# $lgbm$param_fijos$learning_rate
# [1] 0.03
#
# $lgbm$param_fijos$feature_fraction
# [1] 0.5
#
# $lgbm$param_fijos$num_leaves
# [1] 512
#
# $lgbm$param_fijos$min_data_in_leaf
# [1] 300

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
 # makeIntegerParam("num_iterations", lower= 100L, upper= 3000L),       # Lu. No voy a optimizar
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.1),          # Lu. Rangos anteriores 0.01 - 0.3
 # makeNumericParam("feature_fraction", lower= 0.5, upper= 1.0),        # Lu. No voy a optimizar
  makeIntegerParam("min_data_in_leaf", lower= 8L, upper= 4096L),       # Lu. Rangos anteriores 1 - 8000
  makeIntegerParam("num_leaves", lower= 8L, upper= 512L)              # Lu. Rangos anteriores 8 - 2048
 # makeNumericParam("bagging_fraction", lower= 0.6, upper= 1.0),        # Lu. No voy a optimizar
 # makeIntegerParam("bagging_freq", lower= 0L, upper= 10L),             # Lu. No voy a optimizar
 # makeIntegerParam("scale_pos_weight", lower= 10L, upper= 40L)         # Lu. No voy a optimizar
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 80    # iteraciones bayesianas. Es la cantidad de veces que prueba hiperparámetros (va iterando de forma inteligente, no prueba todas las combinaciones)

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros     Agrega una nueva columna "clase01"
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# Contar por valor de clase01
dataset_train[, .N, by = clase01]
# Out:
#   clase01 N
# 1 0       162211
# 2 1         2385

# %%
# defino los datos que forma parte del training     # En este caso defini undesampling todo el dataset.
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia2, kind = "L'Ecuyer-CMRG")   #Lu. "L'Ecuyer-CMRG" es un tipo de generador de números aleatorios que permite reproducibilidad.
                                                                  #Esto asegura que cada vez que corras el código, los mismos registros serán seleccionados en el undersampling.
dataset_train[, azar := runif(nrow(dataset_train))]          #Lu. Genera un vector de números aleatorios uniformes entre 0 y 1, de longitud igual al número de filas del dataset.
                                                                  #Dentro de data.table crea una nueva columna llamada azar con estos valores aleatorios.
                                                                  # Estacolumna servirá para seleccionar aleatoriamente qué filas de la clase mayoritaria se mantendrán en el entrenamiento.
dataset_train[, training := 0L]                              #Lu. Crea una columna training inicializada en 0 para marcar qué filas se usarán en el entrenamiento. 0L indica entero (tipo integer).

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),  #Lu. selecciona aleatoriamente una fracción de las filas según el parámetro undersampling
                                                                                                      # asegura que todas las filas de las clases minoritarias se mantengan, sin importar el azar
  training := 1L   # Lu. Marca estas filas como parte del conjunto de entrenamiento.
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83421
# [1] 154

# %%
# Wrapper function to run EstimarGanancia_AUC_lightgbm with multiple seeds      #Lu. Debajo código modificado para que use las 5 semillas solo cuando AUC encuentra un máximo
#EstimarGanancia_AUC_lightgbm_multiseed <- function(x) {
  # Generate 5 random seeds by repeatedly calling generate_primes              # Lu. Adapté el codigo para que use 5 semillas en la BO y evitar overfitting eligiendo los hiperparámetros.
 # seeds <- replicate(5, generate_primes(min = 100000, max = 999999))
 # auc_values <- numeric(length(seeds))

 # for (i in seq_along(seeds)) {
 #   auc_values[i] <- EstimarGanancia_AUC_lightgbm(x, seeds[i])
 # }

 # average_auc <- mean(auc_values)
 # message(format(Sys.time(), "%a %b %d %X %Y"), " Average AUC across seeds: ", average_auc)
 # return(average_auc)
#}

# %%
# Wrapper adaptativo: primero una semilla, luego 5 si mejora el máximo histórico
#EstimarGanancia_AUC_lightgbm_multiseed <- local({

  # Variable interna para guardar el mejor AUC histórico
#  best_auc_global <- -Inf

#  function(x) {
    # Semilla base (rápida)
#    seed_base <- PARAM$semilla_primigenia
#    auc_base <- EstimarGanancia_AUC_lightgbm(x, seed_base)

    # Si este AUC supera el mejor hasta ahora → validamos con 5 semillas
#    if (auc_base > best_auc_global) {
#      message("Nuevo mejor AUC con una semilla: ", round(auc_base, 5),
#              " → evaluando con 5 semillas...")

      # Generar 5 semillas aleatorias
#      seeds <- replicate(5, generate_primes(min = 100000, max = 999999))
#      auc_values <- numeric(length(seeds))

#      for (i in seq_along(seeds)) {
#        auc_values[i] <- EstimarGanancia_AUC_lightgbm(x, seeds[i])
#      }

#      average_auc <- mean(auc_values)
#      message("Promedio AUC en 5 semillas: ", round(average_auc, 5))

      # Si realmente fue mejor, actualizamos el histórico
#      if (average_auc > best_auc_global) {
#        best_auc_global <<- average_auc
#      }

#      return(average_auc)

#    } else {
      # No supera al mejor histórico → no gastamos tiempo en 5 semillas
#      message("AUC ", round(auc_base, 5),
#              " no supera al mejor histórico (", round(best_auc_global, 5), ")")
#      return(auc_base)
#    }
#  }
#})

# %%
# ============================================================
# CONFIGURACIÓN GLOBAL
# ============================================================
if( !require("filelock") ) install.packages("filelock")         # Lu.
require("filelock")

# %%
# Archivo donde se guarda el mejor AUC global
best_auc_file <- "best_auc_global.RDS"
log_file <- "bo_eval_log.csv"

# Función auxiliar: genera una semilla aleatoria basada en primos
generate_primes <- function(min = 100000, max = 999999) {
  primes <- primes::generate_primes(min = min, max = max)
  sample(primes, 1)
}

# %%
# ============================================================
# FUNCIONES DE SINCRONIZACIÓN SEGURA CON FILELOCK
# ============================================================
read_best_auc <- function() {
  lockfile <- paste0(best_auc_file, ".lock")
  lock <- lock(lockfile, exclusive = FALSE, timeout = 1000)
  on.exit(unlock(lock))
  if (file.exists(best_auc_file)) {
    val <- tryCatch(readRDS(best_auc_file), error = function(e) -Inf)
  } else {
    val <- -Inf
  }
  return(val)
}

write_best_auc <- function(x) {
  lockfile <- paste0(best_auc_file, ".lock")
  lock <- lock(lockfile, exclusive = TRUE, timeout = 1000)
  on.exit(unlock(lock))
  saveRDS(x, best_auc_file)
}

append_log <- function(iter_info) {
  lockfile <- paste0(log_file, ".lock")
  lock <- lock(lockfile, exclusive = TRUE, timeout = 1000)
  on.exit(unlock(lock))
  write.table(
    iter_info, file = log_file, sep = ",", append = TRUE,
    col.names = !file.exists(log_file), row.names = FALSE
  )
}

# %%
# ============================================================
# FUNCIÓN ADAPTATIVA MULTISEED
# ============================================================
EstimarGanancia_AUC_lightgbm_multiseed <- function(x) {
  best_auc_global <- read_best_auc()

  # --- Paso 1: probar con una semilla base
  seed_base <- PARAM$semilla_primigenia
  auc_base <- EstimarGanancia_AUC_lightgbm(x, seed_base)

  append_log(data.frame(
    timestamp = format(Sys.time(), "%Y-%m-%d %H:%M:%S"),
    auc = auc_base,
    seed = seed_base,
    mode = "base",
    stringsAsFactors = FALSE
  ))

  # --- Paso 2: si mejora el mejor histórico, evaluar con 5 semillas
  if (auc_base > best_auc_global) {
    message("Nuevo mejor AUC con una semilla: ", round(auc_base, 5),
            " → evaluando con 5 semillas...")

    seeds <- replicate(5, generate_primes())
    auc_values <- numeric(length(seeds))

    for (i in seq_along(seeds)) {
      auc_values[i] <- EstimarGanancia_AUC_lightgbm(x, seeds[i])
      append_log(data.frame(
        timestamp = format(Sys.time(), "%Y-%m-%d %H:%M:%S"),
        auc = auc_values[i],
        seed = seeds[i],
        mode = paste0("5seed_run_", i),
        stringsAsFactors = FALSE
      ))
    }

    average_auc <- mean(auc_values)
    append_log(data.frame(
      timestamp = format(Sys.time(), "%Y-%m-%d %H:%M:%S"),
      auc = average_auc,
      seed = NA,
      mode = "5seed_average",
      stringsAsFactors = FALSE
    ))

    message("Promedio AUC en 5 semillas: ", round(average_auc, 5))

    if (average_auc > best_auc_global) {
      write_best_auc(average_auc)
    }
    return(average_auc)

  } else {
    message("AUC ", round(auc_base, 5),
            " no supera al mejor histórico (", round(best_auc_global, 5), ")")
    return(auc_base)
  }
}

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x, seed) { # Modified function definition to accept seed

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)
  param_completo$seed <- seed # Use the passed seed

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,    # Lu. Quedó definido 5 folds. Valor confiable para la maroria de los datasets. No tiene sentido optimizarlo
    stratified= TRUE,                                # Lu. Importante porque hay clases desbalanceadas
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm_multiseed # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa.     Lu. Son los rangos de valores de los hiperparametros a optimizar
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Sun Nov 09 04:50:39 PM 2025 AUC 0.927665924758887
#
# Nuevo mejor AUC con una semilla: 0.92767 → evaluando con 5 semillas...
#
# Sun Nov 09 04:52:51 PM 2025 AUC 0.928021264524036
#
# Sun Nov 09 04:54:43 PM 2025 AUC 0.927621944437728
#
# Sun Nov 09 04:56:29 PM 2025 AUC 0.927587646711062
#
# Sun Nov 09 04:58:07 PM 2025 AUC 0.927022985044957
#
# Sun Nov 09 04:59:47 PM 2025 AUC 0.927368073887187
#
# Promedio AUC en 5 semillas: 0.92752
#
# Sun Nov 09 05:01:00 PM 2025 AUC 0.92847874863679
#
# Nuevo mejor AUC con una semilla: 0.92848 → evaluando con 5 semillas...
#
# Sun Nov 09 05:02:20 PM 2025 AUC 0.92815144319435
#
# Sun Nov 09 05:03:42 PM 2025 AUC 0.928475894400426
#
# Sun Nov 09 05:04:55 PM 2025 AUC 0.927333318614364
#
# Sun Nov 09 05:06:14 PM 2025 AUC 0.928244170539498
#
# Sun Nov 09 05:07:45 PM 2025 AUC 0.927701261110279
#
# Promedio AUC en 5 semillas: 0.92798
#
# Sun Nov 09 05:10:31 PM 2025 AUC 0.926315279126167
#
# AUC 0.92632 no supera al mejor histórico (0.92798)
#
# Sun Nov 09 05:12:45 PM 2025 AUC 0.928390443630117
#
# Nuevo mejor AUC con una semilla: 0.92839 → evaluando con 5 semillas...
#
# Sun Nov 09 05:14:51 PM 2025 AUC 0.928612033686924
#
# Sun Nov 09 05:17:14 PM 2025 AUC 0.928171645819006
#
# Sun Nov 09 05:18:58 PM 2025 AUC 0.927872298194178
#
# Sun Nov 09 05:20:52 PM 2025 AUC 0.928036950942574
#
# Sun Nov 09 05:22:56 PM 2025 AUC 0.927285934733608
#
# Promedio AUC en 5 semillas: 0.928
#
# Sun Nov 09 05:24:49 PM 2025 AUC 0.926921079245628
#
# AUC 0.92692 no supera al mejor histórico (0.928)
#
# Sun Nov 09 05:26:47 PM 2025 AUC 0.929466807544626
#
# Nuevo mejor AUC con una semilla: 0.92947 → evaluando con 5 semillas...
#
# Sun Nov 09 05:28:59 PM 2025 AUC 0.929667352719583
#
# Sun Nov 09 05:30:51 PM 2025 AUC 0.929187187718499
#
# Sun Nov 09 05:33:00 PM 2025 AUC 0.929674574004702
#
# Sun Nov 09 05:35:29 PM 2025 AUC 0.929269755719263
#
# Sun Nov 09 05:37:29 PM 2025 AUC 0.928471134537336
#
# Promedio AUC en 5 semillas: 0.92925
#
# Sun Nov 09 05:40:49 PM 2025 AUC 0.929258030796506
#
# Nuevo mejor AUC con una semilla: 0.92926 → evaluando con 5 semillas...
#
# Sun Nov 09 05:44:02 PM 2025 AUC 0.930327395561694
#
# Sun Nov 09 05:47:15 PM 2025 AUC 0.931214445631935
#
# Sun Nov 09 05:50:14 PM 2025 AUC 0.930514732910477
#
# Sun Nov 09 05:53:37 PM 2025 AUC 0.929857340096819
#
# Sun Nov 09 05:56:42 PM 2025 AUC 0.929805515708696
#
# Promedio AUC en 5 semillas: 0.93034
#
# Sun Nov 09 05:58:01 PM 2025 AUC 0.928886681813008
#
# AUC 0.92889 no supera al mejor histórico (0.93034)
#
# Sun Nov 09 05:59:25 PM 2025 AUC 0.926320545211496
#
# AUC 0.92632 no supera al mejor histórico (0.93034)
#
# Sun Nov 09 06:00:56 PM 2025 AUC 0.929855643480228
#
# AUC 0.92986 no supera al mejor histórico (0.93034)
#
# Sun Nov 09 06:02:06 PM 2025 AUC 0.928470090914776
#
# AUC 0.92847 no supera al mejor histórico (0.93034)
#
# Sun Nov 09 06:07:18 PM 2025 AUC 0.927884282653655
#
# AUC 0.92788 no supera al mejor histórico (0.93034)
#
# [mbo] 0: learning_rate=0.0622; min_data_in_leaf=3183; num_leaves=172 : y = 0.928 : 683.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0702; min_data_in_leaf=1427; num_leaves=403 : y = 0.928 : 478.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0368; min_data_in_leaf=41; num_leaves=363 : y = 0.926 : 165.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0459; min_data_in_leaf=2859; num_leaves=102 : y = 0.928 : 745.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0634; min_data_in_leaf=2437; num_leaves=213 : y = 0.927 : 113.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0272; min_data_in_leaf=1077; num_leaves=34 : y = 0.929 : 759.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0134; min_data_in_leaf=652; num_leaves=483 : y = 0.93 : 1153.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0865; min_data_in_leaf=1894; num_leaves=269 : y = 0.929 : 78.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0779; min_data_in_leaf=4074; num_leaves=330 : y = 0.926 : 84.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0478; min_data_in_leaf=883; num_leaves=434 : y = 0.93 : 91.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0967; min_data_in_leaf=2322; num_leaves=84 : y = 0.928 : 69.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0199; min_data_in_leaf=3721; num_leaves=224 : y = 0.928 : 312.4 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Sun Nov 09 06:10:12 PM 2025 AUC 0.931259407776363
#
# Nuevo mejor AUC con una semilla: 0.93126 → evaluando con 5 semillas...
#
# Sun Nov 09 06:12:58 PM 2025 AUC 0.93050779349134
#
# Sun Nov 09 06:15:59 PM 2025 AUC 0.929690177899906
#
# Sun Nov 09 06:18:50 PM 2025 AUC 0.93026732895853
#
# Sun Nov 09 06:22:27 PM 2025 AUC 0.930903103087376
#
# Sun Nov 09 06:25:17 PM 2025 AUC 0.930193095134588
#
# Promedio AUC en 5 semillas: 0.93031
#
# [mbo] 1: learning_rate=0.0153; min_data_in_leaf=795; num_leaves=468 : y = 0.93 : 1078.3 secs : infill_ei
#
# Saved the current state after iteration 2 in the file bayesiana.RDATA.
#
# Sun Nov 09 06:27:24 PM 2025 AUC 0.930046863664957
#
# AUC 0.93005 no supera al mejor histórico (0.93034)
#
# [mbo] 2: learning_rate=0.0237; min_data_in_leaf=716; num_leaves=281 : y = 0.93 : 126.6 secs : infill_ei
#
# Sun Nov 09 06:28:45 PM 2025 AUC 0.929320654932222
#
# AUC 0.92932 no supera al mejor histórico (0.93034)
#
# [mbo] 3: learning_rate=0.0926; min_data_in_leaf=443; num_leaves=477 : y = 0.929 : 80.1 secs : infill_ei
#
# Sun Nov 09 06:30:09 PM 2025 AUC 0.930125426799345
#
# AUC 0.93013 no supera al mejor histórico (0.93034)
#
# [mbo] 4: learning_rate=0.069; min_data_in_leaf=698; num_leaves=512 : y = 0.93 : 83.6 secs : infill_ei
#
# Sun Nov 09 06:34:05 PM 2025 AUC 0.930803148952937
#
# Nuevo mejor AUC con una semilla: 0.9308 → evaluando con 5 semillas...
#
# Sun Nov 09 06:38:04 PM 2025 AUC 0.931634103290601
#
# Sun Nov 09 06:42:02 PM 2025 AUC 0.930637412576595
#
# Sun Nov 09 06:46:04 PM 2025 AUC 0.93053957091324
#
# Sun Nov 09 06:49:49 PM 2025 AUC 0.931294433334469
#
# Sun Nov 09 06:54:04 PM 2025 AUC 0.929448309024449
#
# Promedio AUC en 5 semillas: 0.93071
#
# [mbo] 5: learning_rate=0.01; min_data_in_leaf=720; num_leaves=512 : y = 0.931 : 1434.9 secs : infill_ei
#
# Saved the current state after iteration 6 in the file bayesiana.RDATA.
#
# Sun Nov 09 06:58:23 PM 2025 AUC 0.930059738872941
#
# AUC 0.93006 no supera al mejor histórico (0.93071)
#
# [mbo] 6: learning_rate=0.0101; min_data_in_leaf=1004; num_leaves=512 : y = 0.93 : 258.6 secs : infill_ei
#
# Sun Nov 09 06:59:31 PM 2025 AUC 0.93061123531526
#
# AUC 0.93061 no supera al mejor histórico (0.93071)
#
# [mbo] 7: learning_rate=0.0999; min_data_in_leaf=700; num_leaves=17 : y = 0.931 : 67.8 secs : infill_ei
#
# Sun Nov 09 07:00:43 PM 2025 AUC 0.929007049184502
#
# AUC 0.92901 no supera al mejor histórico (0.93071)
#
# [mbo] 8: learning_rate=0.1; min_data_in_leaf=843; num_leaves=236 : y = 0.929 : 71.6 secs : infill_ei
#
# Sun Nov 09 07:05:24 PM 2025 AUC 0.93096178173223
#
# Nuevo mejor AUC con una semilla: 0.93096 → evaluando con 5 semillas...
#
# Sun Nov 09 07:09:34 PM 2025 AUC 0.930244470118017
#
# Sun Nov 09 07:13:54 PM 2025 AUC 0.930803300018245
#
# Sun Nov 09 07:17:45 PM 2025 AUC 0.931416409765387
#
# Sun Nov 09 07:21:44 PM 2025 AUC 0.92996629183777
#
# Sun Nov 09 07:25:42 PM 2025 AUC 0.931175599828105
#
# Promedio AUC en 5 semillas: 0.93072
#
# [mbo] 9: learning_rate=0.0202; min_data_in_leaf=695; num_leaves=8 : y = 0.931 : 1498.7 secs : infill_ei
#
# Saved the current state after iteration 10 in the file bayesiana.RDATA.
#
# Sun Nov 09 07:27:28 PM 2025 AUC 0.930893592459123
#
# Nuevo mejor AUC con una semilla: 0.93089 → evaluando con 5 semillas...
#
# Sun Nov 09 07:29:06 PM 2025 AUC 0.930121560769581
#
# Sun Nov 09 07:30:28 PM 2025 AUC 0.929530989706349
#
# Sun Nov 09 07:32:09 PM 2025 AUC 0.930002290074707
#
# Sun Nov 09 07:33:45 PM 2025 AUC 0.930591615092894
#
# Sun Nov 09 07:35:37 PM 2025 AUC 0.930976737502244
#
# Promedio AUC en 5 semillas: 0.93024
#
# [mbo] 10: learning_rate=0.0681; min_data_in_leaf=587; num_leaves=8 : y = 0.93 : 593.8 secs : infill_ei
#
# Sun Nov 09 07:37:29 PM 2025 AUC 0.930251289068926
#
# AUC 0.93025 no supera al mejor histórico (0.93072)
#
# [mbo] 11: learning_rate=0.0507; min_data_in_leaf=718; num_leaves=8 : y = 0.93 : 112.0 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesiana.RDATA.
#
# Sun Nov 09 07:41:19 PM 2025 AUC 0.931455540636933
#
# Nuevo mejor AUC con una semilla: 0.93146 → evaluando con 5 semillas...
#
# Sun Nov 09 07:45:01 PM 2025 AUC 0.931224900816454
#
# Sun Nov 09 07:48:59 PM 2025 AUC 0.931089275520367
#
# Sun Nov 09 07:52:43 PM 2025 AUC 0.930394686722781
#
# Sun Nov 09 07:56:30 PM 2025 AUC 0.931028648417139
#
# Sun Nov 09 08:00:17 PM 2025 AUC 0.930856461329499
#
# Promedio AUC en 5 semillas: 0.93092
#
# [mbo] 12: learning_rate=0.01; min_data_in_leaf=672; num_leaves=71 : y = 0.931 : 1367.4 secs : infill_ei
#
# Saved the current state after iteration 13 in the file bayesiana.RDATA.
#
# Sun Nov 09 08:06:48 PM 2025 AUC 0.931462072354802
#
# Nuevo mejor AUC con una semilla: 0.93146 → evaluando con 5 semillas...
#
# Sun Nov 09 08:12:05 PM 2025 AUC 0.930596127101364
#
# Sun Nov 09 08:17:37 PM 2025 AUC 0.931104049702646
#
# Sun Nov 09 08:22:45 PM 2025 AUC 0.929795458101086
#
# Sun Nov 09 08:28:44 PM 2025 AUC 0.931014812020591
#
# Sun Nov 09 08:34:33 PM 2025 AUC 0.93080502164246
#
# Promedio AUC en 5 semillas: 0.93066
#
# [mbo] 13: learning_rate=0.0101; min_data_in_leaf=701; num_leaves=11 : y = 0.931 : 2055.6 secs : infill_ei
#
# Saved the current state after iteration 14 in the file bayesiana.RDATA.
#
# Sun Nov 09 08:36:57 PM 2025 AUC 0.930366634055957
#
# AUC 0.93037 no supera al mejor histórico (0.93092)
#
# [mbo] 14: learning_rate=0.0183; min_data_in_leaf=639; num_leaves=67 : y = 0.93 : 143.6 secs : infill_ei
#
# Sun Nov 09 08:40:56 PM 2025 AUC 0.93070580810273
#
# AUC 0.93071 no supera al mejor histórico (0.93092)
#
# [mbo] 15: learning_rate=0.01; min_data_in_leaf=538; num_leaves=87 : y = 0.931 : 238.9 secs : infill_ei
#
# Sun Nov 09 08:47:32 PM 2025 AUC 0.930473850625408
#
# AUC 0.93047 no supera al mejor histórico (0.93092)
#
# [mbo] 16: learning_rate=0.01; min_data_in_leaf=480; num_leaves=8 : y = 0.93 : 395.2 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesiana.RDATA.
#
# Sun Nov 09 08:51:29 PM 2025 AUC 0.931267817567867
#
# Nuevo mejor AUC con una semilla: 0.93127 → evaluando con 5 semillas...
#
# Sun Nov 09 08:55:33 PM 2025 AUC 0.93055525449919
#
# Sun Nov 09 08:59:58 PM 2025 AUC 0.931423078394656
#
# Sun Nov 09 09:03:56 PM 2025 AUC 0.930423509194896
#
# Sun Nov 09 09:07:55 PM 2025 AUC 0.931557779275818
#
# Sun Nov 09 09:11:47 PM 2025 AUC 0.93071851918951
#
# Promedio AUC en 5 semillas: 0.93094
#
# [mbo] 17: learning_rate=0.01; min_data_in_leaf=680; num_leaves=228 : y = 0.931 : 1455.1 secs : infill_ei
#
# Saved the current state after iteration 18 in the file bayesiana.RDATA.
#
# Sun Nov 09 09:18:00 PM 2025 AUC 0.927925827843379
#
# AUC 0.92793 no supera al mejor histórico (0.93094)
#
# [mbo] 18: learning_rate=0.0124; min_data_in_leaf=8; num_leaves=512 : y = 0.928 : 372.4 secs : infill_ei
#
# Sun Nov 09 09:19:35 PM 2025 AUC 0.930784326272872
#
# AUC 0.93078 no supera al mejor histórico (0.93094)
#
# [mbo] 19: learning_rate=0.088; min_data_in_leaf=586; num_leaves=8 : y = 0.931 : 94.8 secs : infill_ei
#
# Sun Nov 09 09:20:45 PM 2025 AUC 0.928189870536942
#
# AUC 0.92819 no supera al mejor histórico (0.93094)
#
# [mbo] 20: learning_rate=0.1; min_data_in_leaf=523; num_leaves=74 : y = 0.928 : 69.6 secs : infill_ei
#
# Sun Nov 09 09:25:15 PM 2025 AUC 0.930907783934639
#
# AUC 0.93091 no supera al mejor histórico (0.93094)
#
# [mbo] 21: learning_rate=0.01; min_data_in_leaf=805; num_leaves=144 : y = 0.931 : 268.9 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana.RDATA.
#
# Sun Nov 09 09:29:09 PM 2025 AUC 0.931839234910613
#
# Nuevo mejor AUC con una semilla: 0.93184 → evaluando con 5 semillas...
#
# Sun Nov 09 09:33:10 PM 2025 AUC 0.929919999075092
#
# Sun Nov 09 09:37:50 PM 2025 AUC 0.930841887368415
#
# Sun Nov 09 09:42:25 PM 2025 AUC 0.931561890658615
#
# Sun Nov 09 09:46:33 PM 2025 AUC 0.93039616978687
#
# Sun Nov 09 09:50:38 PM 2025 AUC 0.930682234162162
#
# Promedio AUC en 5 semillas: 0.93068
#
# [mbo] 22: learning_rate=0.01; min_data_in_leaf=700; num_leaves=120 : y = 0.931 : 1522.8 secs : infill_ei
#
# Saved the current state after iteration 23 in the file bayesiana.RDATA.
#
# Sun Nov 09 09:55:10 PM 2025 AUC 0.931331323885793
#
# Nuevo mejor AUC con una semilla: 0.93133 → evaluando con 5 semillas...
#
# Sun Nov 09 09:59:15 PM 2025 AUC 0.929830398957465
#
# Sun Nov 09 10:04:04 PM 2025 AUC 0.931716857350355
#
# Sun Nov 09 10:08:44 PM 2025 AUC 0.930096663534943
#
# Sun Nov 09 10:13:07 PM 2025 AUC 0.930217912277525
#
# Sun Nov 09 10:17:21 PM 2025 AUC 0.931025044132037
#
# Promedio AUC en 5 semillas: 0.93058
#
# [mbo] 23: learning_rate=0.01; min_data_in_leaf=841; num_leaves=194 : y = 0.931 : 1603.0 secs : infill_ei
#
# Saved the current state after iteration 24 in the file bayesiana.RDATA.
#
# Sun Nov 09 10:19:12 PM 2025 AUC 0.926747964254097
#
# AUC 0.92675 no supera al mejor histórico (0.93094)
#
# [mbo] 24: learning_rate=0.1; min_data_in_leaf=4094; num_leaves=8 : y = 0.927 : 110.4 secs : infill_ei
#
# Sun Nov 09 10:20:31 PM 2025 AUC 0.929686276064998
#
# AUC 0.92969 no supera al mejor histórico (0.93094)
#
# [mbo] 25: learning_rate=0.0856; min_data_in_leaf=740; num_leaves=8 : y = 0.93 : 78.5 secs : infill_ei
#
# Sun Nov 09 10:24:34 PM 2025 AUC 0.931287275892271
#
# Nuevo mejor AUC con una semilla: 0.93129 → evaluando con 5 semillas...
#
# Sun Nov 09 10:29:10 PM 2025 AUC 0.9314097785214
#
# Sun Nov 09 10:33:12 PM 2025 AUC 0.930662288662931
#
# Sun Nov 09 10:37:42 PM 2025 AUC 0.930073913059956
#
# Sun Nov 09 10:41:40 PM 2025 AUC 0.930883939329347
#
# Sun Nov 09 10:45:33 PM 2025 AUC 0.930532872746757
#
# Promedio AUC en 5 semillas: 0.93071
#
# [mbo] 26: learning_rate=0.0101; min_data_in_leaf=802; num_leaves=85 : y = 0.931 : 1501.3 secs : infill_ei
#
# Saved the current state after iteration 27 in the file bayesiana.RDATA.
#
# Sun Nov 09 10:47:24 PM 2025 AUC 0.930520340732905
#
# AUC 0.93052 no supera al mejor histórico (0.93094)
#
# [mbo] 27: learning_rate=0.0907; min_data_in_leaf=645; num_leaves=8 : y = 0.931 : 110.4 secs : infill_ei
#
# Sun Nov 09 10:49:19 PM 2025 AUC 0.929840113711639
#
# AUC 0.92984 no supera al mejor histórico (0.93094)
#
# [mbo] 28: learning_rate=0.0546; min_data_in_leaf=681; num_leaves=8 : y = 0.93 : 114.4 secs : infill_ei
#
# Sun Nov 09 10:50:41 PM 2025 AUC 0.929944940457397
#
# AUC 0.92994 no supera al mejor histórico (0.93094)
#
# [mbo] 29: learning_rate=0.0815; min_data_in_leaf=591; num_leaves=365 : y = 0.93 : 82.2 secs : infill_ei
#
# Sun Nov 09 10:54:53 PM 2025 AUC 0.93097817217494
#
# Nuevo mejor AUC con una semilla: 0.93098 → evaluando con 5 semillas...
#
# Sun Nov 09 10:59:00 PM 2025 AUC 0.931508842441635
#
# Sun Nov 09 11:02:56 PM 2025 AUC 0.931027952581454
#
# Sun Nov 09 11:06:58 PM 2025 AUC 0.930313770596687
#
# Sun Nov 09 11:10:57 PM 2025 AUC 0.930771977181666
#
# Sun Nov 09 11:15:20 PM 2025 AUC 0.93148805081936
#
# Promedio AUC en 5 semillas: 0.93102
#
# [mbo] 30: learning_rate=0.01; min_data_in_leaf=796; num_leaves=316 : y = 0.931 : 1478.2 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Sun Nov 09 11:19:23 PM 2025 AUC 0.930834511498507
#
# AUC 0.93083 no supera al mejor histórico (0.93102)
#
# [mbo] 31: learning_rate=0.01; min_data_in_leaf=745; num_leaves=272 : y = 0.931 : 242.9 secs : infill_ei
#
# Sun Nov 09 11:21:12 PM 2025 AUC 0.93163698114133
#
# Nuevo mejor AUC con una semilla: 0.93164 → evaluando con 5 semillas...
#
# Sun Nov 09 11:23:28 PM 2025 AUC 0.93092340961076
#
# Sun Nov 09 11:25:34 PM 2025 AUC 0.930260090321379
#
# Sun Nov 09 11:27:20 PM 2025 AUC 0.930977987786335
#
# Sun Nov 09 11:29:12 PM 2025 AUC 0.932192275653899
#
# Sun Nov 09 11:30:56 PM 2025 AUC 0.931551010668773
#
# Promedio AUC en 5 semillas: 0.93118
#
# [mbo] 32: learning_rate=0.0361; min_data_in_leaf=798; num_leaves=16 : y = 0.931 : 691.8 secs : infill_ei
#
# Saved the current state after iteration 33 in the file bayesiana.RDATA.
#
# Sun Nov 09 11:34:09 PM 2025 AUC 0.930884971576151
#
# AUC 0.93088 no supera al mejor histórico (0.93118)
#
# [mbo] 33: learning_rate=0.0302; min_data_in_leaf=779; num_leaves=8 : y = 0.931 : 192.8 secs : infill_ei
#
# Sun Nov 09 11:35:58 PM 2025 AUC 0.930200880930392
#
# AUC 0.9302 no supera al mejor histórico (0.93118)
#
# [mbo] 34: learning_rate=0.0405; min_data_in_leaf=805; num_leaves=135 : y = 0.93 : 108.2 secs : infill_ei
#
# Sun Nov 09 11:37:08 PM 2025 AUC 0.92956214350597
#
# AUC 0.92956 no supera al mejor histórico (0.93118)
#
# [mbo] 35: learning_rate=0.1; min_data_in_leaf=276; num_leaves=8 : y = 0.93 : 70.3 secs : infill_ei
#
# Sun Nov 09 11:39:17 PM 2025 AUC 0.93021349178978
#
# AUC 0.93021 no supera al mejor histórico (0.93118)
#
# [mbo] 36: learning_rate=0.0386; min_data_in_leaf=551; num_leaves=8 : y = 0.93 : 128.5 secs : infill_ei
#
# Sun Nov 09 11:43:36 PM 2025 AUC 0.930857420929287
#
# AUC 0.93086 no supera al mejor histórico (0.93118)
#
# [mbo] 37: learning_rate=0.01; min_data_in_leaf=725; num_leaves=360 : y = 0.931 : 258.5 secs : infill_ei
#
# Saved the current state after iteration 38 in the file bayesiana.RDATA.
#
# Sun Nov 09 11:44:49 PM 2025 AUC 0.927729853194915
#
# AUC 0.92773 no supera al mejor histórico (0.93118)
#
# [mbo] 38: learning_rate=0.1; min_data_in_leaf=2047; num_leaves=512 : y = 0.928 : 72.0 secs : infill_ei
#
# Sun Nov 09 11:46:49 PM 2025 AUC 0.930929158593794
#
# AUC 0.93093 no supera al mejor histórico (0.93118)
#
# [mbo] 39: learning_rate=0.0357; min_data_in_leaf=719; num_leaves=13 : y = 0.931 : 119.5 secs : infill_ei
#
# Sun Nov 09 11:48:06 PM 2025 AUC 0.929391152027857
#
# AUC 0.92939 no supera al mejor histórico (0.93118)
#
# [mbo] 40: learning_rate=0.0809; min_data_in_leaf=335; num_leaves=8 : y = 0.929 : 76.7 secs : infill_ei
#
# Sun Nov 09 11:54:01 PM 2025 AUC 0.92787728167864
#
# AUC 0.92788 no supera al mejor histórico (0.93118)
#
# [mbo] 41: learning_rate=0.01; min_data_in_leaf=2993; num_leaves=512 : y = 0.928 : 354.8 secs : infill_ei
#
# Saved the current state after iteration 42 in the file bayesiana.RDATA.
#
# Sun Nov 09 11:56:54 PM 2025 AUC 0.930957665842438
#
# AUC 0.93096 no supera al mejor histórico (0.93118)
#
# [mbo] 42: learning_rate=0.0344; min_data_in_leaf=830; num_leaves=8 : y = 0.931 : 172.8 secs : infill_ei
#
# Sun Nov 09 11:58:44 PM 2025 AUC 0.930869699466866
#
# AUC 0.93087 no supera al mejor histórico (0.93118)
#
# [mbo] 43: learning_rate=0.0377; min_data_in_leaf=879; num_leaves=48 : y = 0.931 : 109.0 secs : infill_ei
#
# Mon Nov 10 12:00:08 AM 2025 AUC 0.92766824980525
#
# AUC 0.92767 no supera al mejor histórico (0.93118)
#
# [mbo] 44: learning_rate=0.1; min_data_in_leaf=1498; num_leaves=8 : y = 0.928 : 84.1 secs : infill_ei
#
# Mon Nov 10 12:01:19 AM 2025 AUC 0.929811948980665
#
# AUC 0.92981 no supera al mejor histórico (0.93118)
#
# [mbo] 45: learning_rate=0.1; min_data_in_leaf=941; num_leaves=512 : y = 0.93 : 70.3 secs : infill_ei
#
# Mon Nov 10 12:03:38 AM 2025 AUC 0.9304181858142
#
# AUC 0.93042 no supera al mejor histórico (0.93118)
#
# [mbo] 46: learning_rate=0.0356; min_data_in_leaf=770; num_leaves=8 : y = 0.93 : 139.0 secs : infill_ei
#
# Mon Nov 10 12:05:18 AM 2025 AUC 0.931271189345936
#
# Nuevo mejor AUC con una semilla: 0.93127 → evaluando con 5 semillas...
#
# Mon Nov 10 12:06:48 AM 2025 AUC 0.929959576686943
#
# Mon Nov 10 12:08:18 AM 2025 AUC 0.93025419261565
#
# Mon Nov 10 12:10:03 AM 2025 AUC 0.930730064349464
#
# Mon Nov 10 12:11:47 AM 2025 AUC 0.930671500388061
#
# Mon Nov 10 12:13:23 AM 2025 AUC 0.930293870750157
#
# Promedio AUC en 5 semillas: 0.93038
#
# [mbo] 47: learning_rate=0.0365; min_data_in_leaf=693; num_leaves=52 : y = 0.93 : 584.2 secs : infill_ei
#
# Saved the current state after iteration 48 in the file bayesiana.RDATA.
#
# Mon Nov 10 12:16:14 AM 2025 AUC 0.931509917249739
#
# Nuevo mejor AUC con una semilla: 0.93151 → evaluando con 5 semillas...
#
# Mon Nov 10 12:18:29 AM 2025 AUC 0.930356149530494
#
# Mon Nov 10 12:21:11 AM 2025 AUC 0.930774722660016
#
# Mon Nov 10 12:23:47 AM 2025 AUC 0.930284529522972
#
# Mon Nov 10 12:26:30 AM 2025 AUC 0.931409338511823
#
# Mon Nov 10 12:28:48 AM 2025 AUC 0.931081415352834
#
# Promedio AUC en 5 semillas: 0.93078
#
# [mbo] 48: learning_rate=0.0309; min_data_in_leaf=803; num_leaves=13 : y = 0.931 : 924.5 secs : infill_ei
#
# Saved the current state after iteration 49 in the file bayesiana.RDATA.
#
# Mon Nov 10 12:30:06 AM 2025 AUC 0.929134535389485
#
# AUC 0.92913 no supera al mejor histórico (0.93118)
#
# [mbo] 49: learning_rate=0.0777; min_data_in_leaf=656; num_leaves=280 : y = 0.929 : 77.0 secs : infill_ei
#
# Mon Nov 10 12:32:39 AM 2025 AUC 0.930006404458768
#
# AUC 0.93001 no supera al mejor histórico (0.93118)
#
# [mbo] 50: learning_rate=0.0203; min_data_in_leaf=1286; num_leaves=485 : y = 0.93 : 152.9 secs : infill_ei
#
# Mon Nov 10 12:34:41 AM 2025 AUC 0.929953647386293
#
# AUC 0.92995 no supera al mejor histórico (0.93118)
#
# [mbo] 51: learning_rate=0.0336; min_data_in_leaf=764; num_leaves=386 : y = 0.93 : 122.0 secs : infill_ei
#
# Mon Nov 10 12:37:26 AM 2025 AUC 0.931437051399316
#
# Nuevo mejor AUC con una semilla: 0.93144 → evaluando con 5 semillas...
#
# Mon Nov 10 12:39:55 AM 2025 AUC 0.930787824253966
#
# Mon Nov 10 12:42:26 AM 2025 AUC 0.930733163315321
#
# Mon Nov 10 12:44:25 AM 2025 AUC 0.93082445587425
#
# Mon Nov 10 12:46:54 AM 2025 AUC 0.931110287914517
#
# Mon Nov 10 12:48:59 AM 2025 AUC 0.931776040363485
#
# Promedio AUC en 5 semillas: 0.93105
#
# [mbo] 52: learning_rate=0.0289; min_data_in_leaf=718; num_leaves=17 : y = 0.931 : 856.8 secs : infill_ei
#
# Saved the current state after iteration 53 in the file bayesiana.RDATA.
#
# Mon Nov 10 12:50:30 AM 2025 AUC 0.925246335269495
#
# AUC 0.92525 no supera al mejor histórico (0.93118)
#
# [mbo] 53: learning_rate=0.0922; min_data_in_leaf=195; num_leaves=256 : y = 0.925 : 90.7 secs : infill_ei
#
# Mon Nov 10 12:53:26 AM 2025 AUC 0.930461089448314
#
# AUC 0.93046 no supera al mejor histórico (0.93118)
#
# [mbo] 54: learning_rate=0.0208; min_data_in_leaf=520; num_leaves=11 : y = 0.93 : 175.2 secs : infill_ei
#
# Mon Nov 10 12:55:04 AM 2025 AUC 0.92886588967686
#
# AUC 0.92887 no supera al mejor histórico (0.93118)
#
# [mbo] 55: learning_rate=0.0494; min_data_in_leaf=1970; num_leaves=291 : y = 0.929 : 98.2 secs : infill_ei
#
# Mon Nov 10 12:59:04 AM 2025 AUC 0.930077659689266
#
# AUC 0.93008 no supera al mejor histórico (0.93118)
#
# [mbo] 56: learning_rate=0.0101; min_data_in_leaf=784; num_leaves=242 : y = 0.93 : 238.9 secs : infill_ei
#
# Saved the current state after iteration 57 in the file bayesiana.RDATA.
#
# Mon Nov 10 01:00:19 AM 2025 AUC 0.928350122422521
#
# AUC 0.92835 no supera al mejor histórico (0.93118)
#
# [mbo] 57: learning_rate=0.0957; min_data_in_leaf=1759; num_leaves=330 : y = 0.928 : 74.6 secs : infill_ei
#
# Mon Nov 10 01:02:24 AM 2025 AUC 0.930297741150509
#
# AUC 0.9303 no supera al mejor histórico (0.93118)
#
# [mbo] 58: learning_rate=0.0359; min_data_in_leaf=778; num_leaves=12 : y = 0.93 : 124.4 secs : infill_ei
#
# Mon Nov 10 01:04:15 AM 2025 AUC 0.928012596248086
#
# AUC 0.92801 no supera al mejor histórico (0.93118)
#
# [mbo] 59: learning_rate=0.0638; min_data_in_leaf=3152; num_leaves=407 : y = 0.928 : 110.7 secs : infill_ei
#
# Mon Nov 10 01:08:37 AM 2025 AUC 0.930551987044734
#
# AUC 0.93055 no supera al mejor histórico (0.93118)
#
# [mbo] 60: learning_rate=0.0123; min_data_in_leaf=1402; num_leaves=427 : y = 0.931 : 261.4 secs : infill_ei
#
# Mon Nov 10 01:11:20 AM 2025 AUC 0.927394998717062
#
# AUC 0.92739 no supera al mejor histórico (0.93118)
#
# [mbo] 61: learning_rate=0.0295; min_data_in_leaf=2714; num_leaves=179 : y = 0.927 : 162.8 secs : infill_ei
#
# Saved the current state after iteration 62 in the file bayesiana.RDATA.
#
# Mon Nov 10 01:13:33 AM 2025 AUC 0.930810813373063
#
# AUC 0.93081 no supera al mejor histórico (0.93118)
#
# [mbo] 62: learning_rate=0.0187; min_data_in_leaf=812; num_leaves=38 : y = 0.931 : 132.2 secs : infill_ei
#
# Mon Nov 10 01:15:47 AM 2025 AUC 0.928844739447701
#
# AUC 0.92884 no supera al mejor histórico (0.93118)
#
# [mbo] 63: learning_rate=0.0342; min_data_in_leaf=2020; num_leaves=245 : y = 0.929 : 133.4 secs : infill_ei
#
# Mon Nov 10 01:17:13 AM 2025 AUC 0.927817730582585
#
# AUC 0.92782 no supera al mejor histórico (0.93118)
#
# [mbo] 64: learning_rate=0.0704; min_data_in_leaf=3463; num_leaves=31 : y = 0.928 : 86.0 secs : infill_ei
#
# Mon Nov 10 01:18:48 AM 2025 AUC 0.927958469036237
#
# AUC 0.92796 no supera al mejor histórico (0.93118)
#
# [mbo] 65: learning_rate=0.0612; min_data_in_leaf=2876; num_leaves=456 : y = 0.928 : 94.5 secs : infill_ei
#
# Mon Nov 10 01:20:00 AM 2025 AUC 0.928246300292146
#
# AUC 0.92825 no supera al mejor histórico (0.93118)
#
# [mbo] 66: learning_rate=0.0936; min_data_in_leaf=555; num_leaves=78 : y = 0.928 : 71.1 secs : infill_ei
#
# Mon Nov 10 01:21:19 AM 2025 AUC 0.927248305537988
#
# AUC 0.92725 no supera al mejor histórico (0.93118)
#
# [mbo] 67: learning_rate=0.0944; min_data_in_leaf=3702; num_leaves=406 : y = 0.927 : 78.5 secs : infill_ei
#
# Mon Nov 10 01:23:46 AM 2025 AUC 0.927238124436638
#
# AUC 0.92724 no supera al mejor histórico (0.93118)
#
# [mbo] 68: learning_rate=0.0476; min_data_in_leaf=76; num_leaves=497 : y = 0.927 : 146.6 secs : infill_ei
#
# Saved the current state after iteration 69 in the file bayesiana.RDATA.
#
# Mon Nov 10 01:26:12 AM 2025 AUC 0.929529709839983
#
# AUC 0.92953 no supera al mejor histórico (0.93118)
#
# [mbo] 69: learning_rate=0.0308; min_data_in_leaf=1565; num_leaves=77 : y = 0.93 : 145.8 secs : infill_ei
#
# Mon Nov 10 01:28:15 AM 2025 AUC 0.929265637078839
#
# AUC 0.92927 no supera al mejor histórico (0.93118)
#
# [mbo] 70: learning_rate=0.0251; min_data_in_leaf=1190; num_leaves=83 : y = 0.929 : 122.0 secs : infill_ei
#
# Mon Nov 10 01:29:37 AM 2025 AUC 0.929290502728875
#
# AUC 0.92929 no supera al mejor histórico (0.93118)
#
# [mbo] 71: learning_rate=0.0743; min_data_in_leaf=1235; num_leaves=221 : y = 0.929 : 81.4 secs : infill_ei
#
# Mon Nov 10 01:32:18 AM 2025 AUC 0.9307428132515
#
# AUC 0.93074 no supera al mejor histórico (0.93118)
#
# [mbo] 72: learning_rate=0.021; min_data_in_leaf=759; num_leaves=13 : y = 0.931 : 161.0 secs : infill_ei
#
# Mon Nov 10 01:33:55 AM 2025 AUC 0.929002076522327
#
# AUC 0.929 no supera al mejor histórico (0.93118)
#
# [mbo] 73: learning_rate=0.0575; min_data_in_leaf=2130; num_leaves=326 : y = 0.929 : 96.5 secs : infill_ei
#
# Saved the current state after iteration 74 in the file bayesiana.RDATA.
#
# Mon Nov 10 01:36:11 AM 2025 AUC 0.927504828366004
#
# AUC 0.9275 no supera al mejor histórico (0.93118)
#
# [mbo] 74: learning_rate=0.0522; min_data_in_leaf=3538; num_leaves=101 : y = 0.928 : 135.2 secs : infill_ei
#
# Mon Nov 10 01:38:21 AM 2025 AUC 0.930972397101289
#
# AUC 0.93097 no supera al mejor histórico (0.93118)
#
# [mbo] 75: learning_rate=0.0302; min_data_in_leaf=744; num_leaves=10 : y = 0.931 : 129.3 secs : infill_ei
#
# Mon Nov 10 01:41:42 AM 2025 AUC 0.931295283037183
#
# Nuevo mejor AUC con una semilla: 0.9313 → evaluando con 5 semillas...
#
# Mon Nov 10 01:45:15 AM 2025 AUC 0.931400447995108
#
# Mon Nov 10 01:48:51 AM 2025 AUC 0.931243375383664
#
# Mon Nov 10 01:52:01 AM 2025 AUC 0.930546395058795
#
# Mon Nov 10 01:54:59 AM 2025 AUC 0.930918742221333
#
# Mon Nov 10 01:58:10 AM 2025 AUC 0.930996896857818
#
# Promedio AUC en 5 semillas: 0.93102
#
# [mbo] 76: learning_rate=0.0135; min_data_in_leaf=668; num_leaves=374 : y = 0.931 : 1189.1 secs : infill_ei
#
# Saved the current state after iteration 77 in the file bayesiana.RDATA.
#
# Mon Nov 10 02:01:23 AM 2025 AUC 0.927102380875153
#
# AUC 0.9271 no supera al mejor histórico (0.93118)
#
# [mbo] 77: learning_rate=0.0306; min_data_in_leaf=3812; num_leaves=43 : y = 0.927 : 191.9 secs : infill_ei
#
# Mon Nov 10 02:04:44 AM 2025 AUC 0.926741157966048
#
# AUC 0.92674 no supera al mejor histórico (0.93118)
#
# [mbo] 78: learning_rate=0.0202; min_data_in_leaf=3359; num_leaves=462 : y = 0.927 : 200.7 secs : infill_ei
#
# Mon Nov 10 02:06:40 AM 2025 AUC 0.93200059707309
#
# Nuevo mejor AUC con una semilla: 0.932 → evaluando con 5 semillas...
#
# Mon Nov 10 02:08:18 AM 2025 AUC 0.930513467640806
#
# Mon Nov 10 02:10:31 AM 2025 AUC 0.931250281365317
#
# Mon Nov 10 02:12:36 AM 2025 AUC 0.930893512545282
#
# Mon Nov 10 02:14:33 AM 2025 AUC 0.931278936548767
#
# Mon Nov 10 02:16:38 AM 2025 AUC 0.93060303680586
#
# Promedio AUC en 5 semillas: 0.93091
#
# [mbo] 79: learning_rate=0.0316; min_data_in_leaf=839; num_leaves=21 : y = 0.931 : 713.8 secs : infill_ei
#
# Saved the current state after iteration 80 in the file bayesiana.RDATA.
#
# Mon Nov 10 02:17:56 AM 2025 AUC 0.926638403271147
#
# AUC 0.92664 no supera al mejor histórico (0.93118)
#
# [mbo] 80: learning_rate=0.0865; min_data_in_leaf=3089; num_leaves=81 : y = 0.927 : 76.7 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"    "min_data_in_leaf" "num_leaves"       "y"
#  [5] "dob"              "eol"              "error.message"    "exec.time"
#  [9] "ei"               "error.model"      "train.time"       "prop.type"
# [13] "propose.time"     "se"               "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate min_data_in_leaf num_leaves
#            <num>            <int>      <int>
# 1:    0.03606381              798         16
# [1] 0.931181

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 120539
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 2048
#
# $early_stopping_rounds
# [1] 200
#
# $learning_rate
# [1] 0.03606381
#
# $feature_fraction
# [1] 0.5
#
# $num_leaves
# [1] 16
#
# $min_data_in_leaf
# [1] 798

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)
#Lu. Eliminar early_stopping_rounds para el entrenamiento final
param_normalizado$early_stopping_rounds <- NULL

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 10 03:11:51 AM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
