# %% [markdown]
# <a href="https://colab.research.google.com/github/luciaphmaestria/labo2025v/blob/main/src/CompetenciaKaggle/12_610_WorkFlow_01_gerencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow | Gerencial Competencia Kaggle

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#------- AGREGO EL EXCEL PARA DATA DRIFTING EXPERIMENTO #2

archivo="Indice-FACPCE.xlsx"

# Si el archivo existe en tu Drive (en b1/datasets), copiarlo a /content/datasets
if [ -f "/content/buckets/b1/datasets/$archivo" ]; then
  cp "/content/buckets/b1/datasets/$archivo" "/content/datasets/$archivo"
else
  echo "No se encontró el archivo en: /content/buckets/b1/datasets/$archivo"
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Dec 01 12:08:51 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660355 35.3 1454494    77.7 1454494  77.7
# Vcells 1226516  9.4 8388608    64.0 1975136  15.1

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 960737

PARAM$experimento <- 6812
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos
#
# **EXPERIMENTO #1. Según lo recomendado mantenemos método Machine Learning.**

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %% [markdown]
# **MODIFICACIÓN EXPERIMENTO #2. Data drifting con  indicador FACPCE. Usa IPC**

# %%
#PASO 1
library(readxl)
library(data.table)
library(dplyr)
fapce <- read_excel("/content/datasets/Indice-FACPCE.xlsx", col_types = "text") %>%
  mutate(
    # ---- FOTO_MES CORREGIDO ----
    # Eliminar el último caracter: "2020050" → "202005"
    foto_mes = gsub("[^0-9]", "", foto_mes),
    foto_mes = substr(foto_mes, 1, 6),

    # ---- IPC ----
    IPC = gsub("[^0-9]", "", IPC),
    IPC = as.numeric(IPC),

    # ---- coeficiente ajustes ----
    coeficiente_de_ajuste = gsub(",", ".", coeficiente_de_ajuste),
    coeficiente_de_ajuste = gsub("[^0-9.]", "", coeficiente_de_ajuste),
    coeficiente_de_ajuste = as.numeric(coeficiente_de_ajuste)
  ) %>%
  as.data.table()
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
#PASO 2
dataset <- as.data.table(dataset)

# asegurar foto_mes como texto tipo "202005"
dataset[, foto_mes := as.character(foto_mes)]
dataset[, foto_mes := gsub("[^0-9]", "", foto_mes)]
dataset[, foto_mes := substr(foto_mes, 1, 6)]

# %%
#PASO 3
cols_borrar <- c("coeficiente_de_ajuste", "coeficiente_de_ajuste.x", "coeficiente_de_ajuste.y")

for (col in cols_borrar) {
  if (col %in% names(dataset)) dataset[, (col) := NULL]
}

# %%
#PASO 4
dataset <- merge(
  dataset,
  fapce[, .(foto_mes, coeficiente_de_ajuste)],
  by = "foto_mes",
  all.x = TRUE
)

# %%
#PASO 5 MERGE POR FOTO_MES
vars_ajustar <- c(
  "mrentabilidad",
  "mrentabilidad_annual",
  "mcomisiones",
  "mactivos_margen",
  "mpasivos_margen",
  "mcuenta_corriente",
  "mcaja_ahorro",
  "mcuentas_saldo",
  "mtarjeta_visa_consumo",
  "mtarjeta_master_consumo",
  "mprestamos_personales",
  "mpayroll",
  "Master_mpagominimo",
  "Visa_mpagominimo"
)

dataset[, (vars_ajustar) := lapply(.SD, as.numeric), .SDcols = vars_ajustar]

# %%
#PASO 6
dataset[
  ,
  (vars_ajustar) := lapply(.SD, function(x) x * coeficiente_de_ajuste),
  .SDcols = vars_ajustar
]

# %%
head(dataset)
# Out:
#   foto_mes numero_de_cliente internet cliente_edad cliente_antiguedad
# 1 202005   29186441          1        61           282
# 2 202005   29187961          1        61           312
# 3 202005   29193101          1        67           365
# 4 202005   29193281          1        54           158
# 5 202005   29198891          1        54           312
# 6 202005   29205441          1        72             6
#   mrentabilidad mrentabilidad_annual mcomisiones mactivos_margen
# 1 NA            NA                   NA          NA
# 2 NA            NA                   NA          NA
# 3 NA            NA                   NA          NA
# 4 NA            NA                   NA          NA
# 5 NA            NA                   NA          NA
# 6 NA            NA                   NA          NA
#   mpasivos_margen ⋯ chomebanking_transacciones ctrx_quarter Master_status
# 1 NA              ⋯  20                         47          0
# 2 NA              ⋯ 228                        232          0
# 3 NA              ⋯ 133                        149          0
# 4 NA              ⋯  10                        115          0
# 5 NA              ⋯ 124                         32          0
# 6 NA              ⋯  41                         32          0
#   Master_fechaalta Master_mpagominimo Visa_status Visa_fechaalta
# 1 6507             NA                 0           7671
# 2 5939             NA                 0           8090
# 3 2026             NA                 0           2026
# 4 3125             NA                 0           3350
# 5 7202             NA                 0           7242
# 6  157             NA                 0            157
#   Visa_mpagominimo clase_ternaria coeficiente_de_ajuste
# 1 NA               CONTINUA       NA
# 2 NA               CONTINUA       NA
# 3 NA               CONTINUA       NA
# 4 NA               CONTINUA       NA
# 5 NA               CONTINUA       NA
# 6 NA               CONTINUA       NA

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
# EXPERIMENTO #2. Por las modificaciones debo vovler a pasar a numerico foto_mes y mpayroll y cliente_edad

atributos_presentes <- function(patributos) {
  atributos <- unique(patributos)
  comun <- intersect(atributos, colnames(dataset))
  return(length(atributos) == length(comun))
}

# --- Necesario 1: foto_mes debe ser numérico PARA LA OPERACIÓN ---
if (atributos_presentes(c("foto_mes"))) {
  dataset[, kmes := as.integer(foto_mes) %% 100]
}

# --- Necesario 2: asegurar tipos numéricos para el cálculo ---
if (atributos_presentes(c("mpayroll", "cliente_edad"))) {
  dataset[, mpayroll := as.numeric(mpayroll)]
  dataset[, cliente_edad := as.numeric(cliente_edad)]
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]
}

# %% [markdown]
# **FIN MODIFICACIÓN EXPERIMENTO #2.**

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "foto_mes"                    "numero_de_cliente"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "coeficiente_de_ajuste"       "kmes"
# [35] "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
# AGREGO TAMBIÉN DE ORDEN 3 Y 6.
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 3                                                     # AGREGO LAGS DE ORDEN 3 Y 6.
dataset[,
  paste0(cols_lagueables, "_lag3") := shift(.SD, 3, NA, "lag"),
  by = numero_de_cliente,
  .SDcols = cols_lagueables
]

# lags de orden 6
dataset[,
  paste0(cols_lagueables, "_lag6") := shift(.SD, 6, NA, "lag"),
  by = numero_de_cliente,
  .SDcols = cols_lagueables
]


# agrego los delta lags
for (vcol in cols_lagueables) {
  dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
  dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
  dataset[, paste0(vcol, "_delta3") := get(vcol) - get(paste0(vcol, "_lag3"))]
  dataset[, paste0(vcol, "_delta6") := get(vcol) - get(paste0(vcol, "_lag6"))]
}

# %% [markdown]
# **MODIFICACIÓN EXPERIMENTO #3. Feature Engineering. Creación de nuevas variables a partir de las originales (no Random Forest)**

# %%
# Creación de Nuevas Variables sin incluir variables del RF

library(data.table)
dataset <- as.data.table(dataset)

################################################################################
### FEATURE 1: RATIOS & RENTABILIDAD (ratio_profitability_score)
###
### Resume el estado económico del cliente basado en:
### - rentabilidad anual
### - variaciones de rentabilidad (delta1, delta2, lag2)
### - ingresos relativos (mpayroll_sobre_edad)
### - margen de activos y pasivos
###
### Un valor ALTO = cliente sano
### Un valor BAJO = podría estar entrando en estrés financiero
################################################################################

dataset[, ratio_profitability_score :=
          scale(mrentabilidad_annual) +
          scale(mrentabilidad_annual_delta1) +
          scale(mrentabilidad_annual_delta2) +
          scale(mrentabilidad_annual_lag2) +
          scale(mpayroll_sobre_edad) +
          scale(mactivos_margen_delta2) +
          scale(mpasivos_margen)
        ]


################################################################################
### FEATURE 2: SALDOS & VARIACIONES (balance_trend_score)
###
### Captura movimientos estructurales del cliente:
### - saldo de cuentas (nivel)
### - variaciones de saldo (delta1, delta2)
### - préstamos personales y sus variaciones
### - límite de tarjetas (proxy de nivel económico)  -->ESTA VARIABLE NO ESTA EN GERENCIAL
###
### Valores ALTOS → crecimiento saludable
### Valores BAJOS → señales de retiro de dinero o reducción de crédito
################################################################################

dataset[, balance_trend_score :=
          scale(mcuentas_saldo) +
          scale(mcuentas_saldo_delta1) +
          scale(mcuentas_saldo_delta2) +
          scale(mprestamos_personales) +
          scale(mprestamos_personales_delta2)
         # scale(Master_mfinanciacion_limite)
        ]


################################################################################
### FEATURE 3: ACTIVIDAD & USO OPERATIVO (activity_behavior_score)
###
### Resume cómo usa el banco:
### - transacciones recientes (ctrx_quarter)
### - uso de Visa (Visa_msaldototal)
### - comisiones (lag1, lag2)
### - operaciones de homebanking
###
### Valores altos → cliente activo
### Valores bajos → cliente desconectándose
################################################################################

dataset[, activity_behavior_score :=
          scale(ctrx_quarter) +
          scale(mtarjeta_visa_consumo) +          # Reemplazo Visa_msaldototal por mtarjeta_visa_consumo, porque en gerencial no tengo esa variable
          scale(mcomisiones_lag1) +
          scale(mcomisiones_lag2) +
          scale(chomebanking_transacciones_delta2)
        ]

# %% [markdown]
# **FIN MODIFICACIÓN EXPERIMENTO #3**

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 294
#   [1] "foto_mes"                           "numero_de_cliente"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "coeficiente_de_ajuste"              "kmes"
#  [35] "mpayroll_sobre_edad"                "internet_lag1"
#  [37] "cliente_edad_lag1"                  "cliente_antiguedad_lag1"
#  [39] "mrentabilidad_lag1"                 "mrentabilidad_annual_lag1"
#  [41] "mcomisiones_lag1"                   "mactivos_margen_lag1"
#  [43] "mpasivos_margen_lag1"               "cproductos_lag1"
#  [45] "mcuenta_corriente_lag1"             "mcaja_ahorro_lag1"
#  [47] "cdescubierto_preacordado_lag1"      "mcuentas_saldo_lag1"
#  [49] "ctarjeta_visa_transacciones_lag1"   "mtarjeta_visa_consumo_lag1"
#  [51] "mtarjeta_master_consumo_lag1"       "mprestamos_personales_lag1"
#  [53] "cpayroll_trx_lag1"                  "mpayroll_lag1"
#  [55] "ccomisiones_mantenimiento_lag1"     "ccallcenter_transacciones_lag1"
#  [57] "chomebanking_transacciones_lag1"    "ctrx_quarter_lag1"
#  [59] "Master_status_lag1"                 "Master_fechaalta_lag1"
#  [61] "Master_mpagominimo_lag1"            "Visa_status_lag1"
#  [63] "Visa_fechaalta_lag1"                "Visa_mpagominimo_lag1"
#  [65] "coeficiente_de_ajuste_lag1"         "kmes_lag1"
#  [67] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [69] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [71] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [73] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [75] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [77] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [79] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [81] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [83] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [85] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [87] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [89] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [91] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [93] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [95] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [97] "coeficiente_de_ajuste_lag2"         "kmes_lag2"
#  [99] "mpayroll_sobre_edad_lag2"           "internet_lag3"
# [101] "cliente_edad_lag3"                  "cliente_antiguedad_lag3"
# [103] "mrentabilidad_lag3"                 "mrentabilidad_annual_lag3"
# [105] "mcomisiones_lag3"                   "mactivos_margen_lag3"
# [107] "mpasivos_margen_lag3"               "cproductos_lag3"
# [109] "mcuenta_corriente_lag3"             "mcaja_ahorro_lag3"
# [111] "cdescubierto_preacordado_lag3"      "mcuentas_saldo_lag3"
# [113] "ctarjeta_visa_transacciones_lag3"   "mtarjeta_visa_consumo_lag3"
# [115] "mtarjeta_master_consumo_lag3"       "mprestamos_personales_lag3"
# [117] "cpayroll_trx_lag3"                  "mpayroll_lag3"
# [119] "ccomisiones_mantenimiento_lag3"     "ccallcenter_transacciones_lag3"
# [121] "chomebanking_transacciones_lag3"    "ctrx_quarter_lag3"
# [123] "Master_status_lag3"                 "Master_fechaalta_lag3"
# [125] "Master_mpagominimo_lag3"            "Visa_status_lag3"
# [127] "Visa_fechaalta_lag3"                "Visa_mpagominimo_lag3"
# [129] "coeficiente_de_ajuste_lag3"         "kmes_lag3"
# [131] "mpayroll_sobre_edad_lag3"           "internet_lag6"
# [133] "cliente_edad_lag6"                  "cliente_antiguedad_lag6"
# [135] "mrentabilidad_lag6"                 "mrentabilidad_annual_lag6"
# [137] "mcomisiones_lag6"                   "mactivos_margen_lag6"
# [139] "mpasivos_margen_lag6"               "cproductos_lag6"
# [141] "mcuenta_corriente_lag6"             "mcaja_ahorro_lag6"
# [143] "cdescubierto_preacordado_lag6"      "mcuentas_saldo_lag6"
# [145] "ctarjeta_visa_transacciones_lag6"   "mtarjeta_visa_consumo_lag6"
# [147] "mtarjeta_master_consumo_lag6"       "mprestamos_personales_lag6"
# [149] "cpayroll_trx_lag6"                  "mpayroll_lag6"
# [151] "ccomisiones_mantenimiento_lag6"     "ccallcenter_transacciones_lag6"
# [153] "chomebanking_transacciones_lag6"    "ctrx_quarter_lag6"
# [155] "Master_status_lag6"                 "Master_fechaalta_lag6"
# [157] "Master_mpagominimo_lag6"            "Visa_status_lag6"
# [159] "Visa_fechaalta_lag6"                "Visa_mpagominimo_lag6"
# [161] "coeficiente_de_ajuste_lag6"         "kmes_lag6"
# [163] "mpayroll_sobre_edad_lag6"           "internet_delta1"
# [165] "internet_delta2"                    "internet_delta3"
# [167] "internet_delta6"                    "cliente_edad_delta1"
# [169] "cliente_edad_delta2"                "cliente_edad_delta3"
# [171] "cliente_edad_delta6"                "cliente_antiguedad_delta1"
# [173] "cliente_antiguedad_delta2"          "cliente_antiguedad_delta3"
# [175] "cliente_antiguedad_delta6"          "mrentabilidad_delta1"
# [177] "mrentabilidad_delta2"               "mrentabilidad_delta3"
# [179] "mrentabilidad_delta6"               "mrentabilidad_annual_delta1"
# [181] "mrentabilidad_annual_delta2"        "mrentabilidad_annual_delta3"
# [183] "mrentabilidad_annual_delta6"        "mcomisiones_delta1"
# [185] "mcomisiones_delta2"                 "mcomisiones_delta3"
# [187] "mcomisiones_delta6"                 "mactivos_margen_delta1"
# [189] "mactivos_margen_delta2"             "mactivos_margen_delta3"
# [191] "mactivos_margen_delta6"             "mpasivos_margen_delta1"
# [193] "mpasivos_margen_delta2"             "mpasivos_margen_delta3"
# [195] "mpasivos_margen_delta6"             "cproductos_delta1"
# [197] "cproductos_delta2"                  "cproductos_delta3"
# [199] "cproductos_delta6"                  "mcuenta_corriente_delta1"
# [201] "mcuenta_corriente_delta2"           "mcuenta_corriente_delta3"
# [203] "mcuenta_corriente_delta6"           "mcaja_ahorro_delta1"
# [205] "mcaja_ahorro_delta2"                "mcaja_ahorro_delta3"
# [207] "mcaja_ahorro_delta6"                "cdescubierto_preacordado_delta1"
# [209] "cdescubierto_preacordado_delta2"    "cdescubierto_preacordado_delta3"
# [211] "cdescubierto_preacordado_delta6"    "mcuentas_saldo_delta1"
# [213] "mcuentas_saldo_delta2"              "mcuentas_saldo_delta3"
# [215] "mcuentas_saldo_delta6"              "ctarjeta_visa_transacciones_delta1"
# [217] "ctarjeta_visa_transacciones_delta2" "ctarjeta_visa_transacciones_delta3"
# [219] "ctarjeta_visa_transacciones_delta6" "mtarjeta_visa_consumo_delta1"
# [221] "mtarjeta_visa_consumo_delta2"       "mtarjeta_visa_consumo_delta3"
# [223] "mtarjeta_visa_consumo_delta6"       "mtarjeta_master_consumo_delta1"
# [225] "mtarjeta_master_consumo_delta2"     "mtarjeta_master_consumo_delta3"
# [227] "mtarjeta_master_consumo_delta6"     "mprestamos_personales_delta1"
# [229] "mprestamos_personales_delta2"       "mprestamos_personales_delta3"
# [231] "mprestamos_personales_delta6"       "cpayroll_trx_delta1"
# [233] "cpayroll_trx_delta2"                "cpayroll_trx_delta3"
# [235] "cpayroll_trx_delta6"                "mpayroll_delta1"
# [237] "mpayroll_delta2"                    "mpayroll_delta3"
# [239] "mpayroll_delta6"                    "ccomisiones_mantenimiento_delta1"
# [241] "ccomisiones_mantenimiento_delta2"   "ccomisiones_mantenimiento_delta3"
# [243] "ccomisiones_mantenimiento_delta6"   "ccallcenter_transacciones_delta1"
# [245] "ccallcenter_transacciones_delta2"   "ccallcenter_transacciones_delta3"
# [247] "ccallcenter_transacciones_delta6"   "chomebanking_transacciones_delta1"
# [249] "chomebanking_transacciones_delta2"  "chomebanking_transacciones_delta3"
# [251] "chomebanking_transacciones_delta6"  "ctrx_quarter_delta1"
# [253] "ctrx_quarter_delta2"                "ctrx_quarter_delta3"
# [255] "ctrx_quarter_delta6"                "Master_status_delta1"
# [257] "Master_status_delta2"               "Master_status_delta3"
# [259] "Master_status_delta6"               "Master_fechaalta_delta1"
# [261] "Master_fechaalta_delta2"            "Master_fechaalta_delta3"
# [263] "Master_fechaalta_delta6"            "Master_mpagominimo_delta1"
# [265] "Master_mpagominimo_delta2"          "Master_mpagominimo_delta3"
# [267] "Master_mpagominimo_delta6"          "Visa_status_delta1"
# [269] "Visa_status_delta2"                 "Visa_status_delta3"
# [271] "Visa_status_delta6"                 "Visa_fechaalta_delta1"
# [273] "Visa_fechaalta_delta2"              "Visa_fechaalta_delta3"
# [275] "Visa_fechaalta_delta6"              "Visa_mpagominimo_delta1"
# [277] "Visa_mpagominimo_delta2"            "Visa_mpagominimo_delta3"
# [279] "Visa_mpagominimo_delta6"            "coeficiente_de_ajuste_delta1"
# [281] "coeficiente_de_ajuste_delta2"       "coeficiente_de_ajuste_delta3"
# [283] "coeficiente_de_ajuste_delta6"       "kmes_delta1"
# [285] "kmes_delta2"                        "kmes_delta3"
# [287] "kmes_delta6"                        "mpayroll_sobre_edad_delta1"
# [289] "mpayroll_sobre_edad_delta2"         "mpayroll_sobre_edad_delta3"
# [291] "mpayroll_sobre_edad_delta6"         "ratio_profitability_score"
# [293] "balance_trend_score"                "activity_behavior_score"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 202005, 202107 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 202005, 202106 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202107)

PARAM$trainingstrategy$training <- c(
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 0.4           # Defino Undersampling 0.4 según consejo EXPERIMENTO #11. Y pruebas propias


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %% [markdown]
# **MODIFICACIÓN POR EXPERIMENTO #16 - Eliminar variables numero_de_cliente y foto_mes**

# %%
# los campos en los que se entrena
#campos_buenos <- copy( setdiff(
 # colnames(dataset), c("clase_ternaria","clase01","azar"))
#)

# %%
# los campos en los que se entrena
# Excluyo las columnas
campos_a_excluir <- c( "clase_ternaria", "clase01","numero_de_cliente","foto_mes", "azar")

campos_buenos <- setdiff(
    colnames(dataset),
    campos_a_excluir
)

# %%
campos_buenos
# Out:
#   [1] "internet"                           "cliente_edad"
#   [3] "cliente_antiguedad"                 "mrentabilidad"
#   [5] "mrentabilidad_annual"               "mcomisiones"
#   [7] "mactivos_margen"                    "mpasivos_margen"
#   [9] "cproductos"                         "mcuenta_corriente"
#  [11] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [13] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [15] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [17] "mprestamos_personales"              "cpayroll_trx"
#  [19] "mpayroll"                           "ccomisiones_mantenimiento"
#  [21] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [23] "ctrx_quarter"                       "Master_status"
#  [25] "Master_fechaalta"                   "Master_mpagominimo"
#  [27] "Visa_status"                        "Visa_fechaalta"
#  [29] "Visa_mpagominimo"                   "coeficiente_de_ajuste"
#  [31] "kmes"                               "mpayroll_sobre_edad"
#  [33] "internet_lag1"                      "cliente_edad_lag1"
#  [35] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [37] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [39] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [41] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [43] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [45] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [47] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [49] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [51] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [53] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [55] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [57] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [59] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [61] "Visa_mpagominimo_lag1"              "coeficiente_de_ajuste_lag1"
#  [63] "kmes_lag1"                          "mpayroll_sobre_edad_lag1"
#  [65] "internet_lag2"                      "cliente_edad_lag2"
#  [67] "cliente_antiguedad_lag2"            "mrentabilidad_lag2"
#  [69] "mrentabilidad_annual_lag2"          "mcomisiones_lag2"
#  [71] "mactivos_margen_lag2"               "mpasivos_margen_lag2"
#  [73] "cproductos_lag2"                    "mcuenta_corriente_lag2"
#  [75] "mcaja_ahorro_lag2"                  "cdescubierto_preacordado_lag2"
#  [77] "mcuentas_saldo_lag2"                "ctarjeta_visa_transacciones_lag2"
#  [79] "mtarjeta_visa_consumo_lag2"         "mtarjeta_master_consumo_lag2"
#  [81] "mprestamos_personales_lag2"         "cpayroll_trx_lag2"
#  [83] "mpayroll_lag2"                      "ccomisiones_mantenimiento_lag2"
#  [85] "ccallcenter_transacciones_lag2"     "chomebanking_transacciones_lag2"
#  [87] "ctrx_quarter_lag2"                  "Master_status_lag2"
#  [89] "Master_fechaalta_lag2"              "Master_mpagominimo_lag2"
#  [91] "Visa_status_lag2"                   "Visa_fechaalta_lag2"
#  [93] "Visa_mpagominimo_lag2"              "coeficiente_de_ajuste_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_lag3"                      "cliente_edad_lag3"
#  [99] "cliente_antiguedad_lag3"            "mrentabilidad_lag3"
# [101] "mrentabilidad_annual_lag3"          "mcomisiones_lag3"
# [103] "mactivos_margen_lag3"               "mpasivos_margen_lag3"
# [105] "cproductos_lag3"                    "mcuenta_corriente_lag3"
# [107] "mcaja_ahorro_lag3"                  "cdescubierto_preacordado_lag3"
# [109] "mcuentas_saldo_lag3"                "ctarjeta_visa_transacciones_lag3"
# [111] "mtarjeta_visa_consumo_lag3"         "mtarjeta_master_consumo_lag3"
# [113] "mprestamos_personales_lag3"         "cpayroll_trx_lag3"
# [115] "mpayroll_lag3"                      "ccomisiones_mantenimiento_lag3"
# [117] "ccallcenter_transacciones_lag3"     "chomebanking_transacciones_lag3"
# [119] "ctrx_quarter_lag3"                  "Master_status_lag3"
# [121] "Master_fechaalta_lag3"              "Master_mpagominimo_lag3"
# [123] "Visa_status_lag3"                   "Visa_fechaalta_lag3"
# [125] "Visa_mpagominimo_lag3"              "coeficiente_de_ajuste_lag3"
# [127] "kmes_lag3"                          "mpayroll_sobre_edad_lag3"
# [129] "internet_lag6"                      "cliente_edad_lag6"
# [131] "cliente_antiguedad_lag6"            "mrentabilidad_lag6"
# [133] "mrentabilidad_annual_lag6"          "mcomisiones_lag6"
# [135] "mactivos_margen_lag6"               "mpasivos_margen_lag6"
# [137] "cproductos_lag6"                    "mcuenta_corriente_lag6"
# [139] "mcaja_ahorro_lag6"                  "cdescubierto_preacordado_lag6"
# [141] "mcuentas_saldo_lag6"                "ctarjeta_visa_transacciones_lag6"
# [143] "mtarjeta_visa_consumo_lag6"         "mtarjeta_master_consumo_lag6"
# [145] "mprestamos_personales_lag6"         "cpayroll_trx_lag6"
# [147] "mpayroll_lag6"                      "ccomisiones_mantenimiento_lag6"
# [149] "ccallcenter_transacciones_lag6"     "chomebanking_transacciones_lag6"
# [151] "ctrx_quarter_lag6"                  "Master_status_lag6"
# [153] "Master_fechaalta_lag6"              "Master_mpagominimo_lag6"
# [155] "Visa_status_lag6"                   "Visa_fechaalta_lag6"
# [157] "Visa_mpagominimo_lag6"              "coeficiente_de_ajuste_lag6"
# [159] "kmes_lag6"                          "mpayroll_sobre_edad_lag6"
# [161] "internet_delta1"                    "internet_delta2"
# [163] "internet_delta3"                    "internet_delta6"
# [165] "cliente_edad_delta1"                "cliente_edad_delta2"
# [167] "cliente_edad_delta3"                "cliente_edad_delta6"
# [169] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [171] "cliente_antiguedad_delta3"          "cliente_antiguedad_delta6"
# [173] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [175] "mrentabilidad_delta3"               "mrentabilidad_delta6"
# [177] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [179] "mrentabilidad_annual_delta3"        "mrentabilidad_annual_delta6"
# [181] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [183] "mcomisiones_delta3"                 "mcomisiones_delta6"
# [185] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [187] "mactivos_margen_delta3"             "mactivos_margen_delta6"
# [189] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [191] "mpasivos_margen_delta3"             "mpasivos_margen_delta6"
# [193] "cproductos_delta1"                  "cproductos_delta2"
# [195] "cproductos_delta3"                  "cproductos_delta6"
# [197] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [199] "mcuenta_corriente_delta3"           "mcuenta_corriente_delta6"
# [201] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [203] "mcaja_ahorro_delta3"                "mcaja_ahorro_delta6"
# [205] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [207] "cdescubierto_preacordado_delta3"    "cdescubierto_preacordado_delta6"
# [209] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [211] "mcuentas_saldo_delta3"              "mcuentas_saldo_delta6"
# [213] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [215] "ctarjeta_visa_transacciones_delta3" "ctarjeta_visa_transacciones_delta6"
# [217] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [219] "mtarjeta_visa_consumo_delta3"       "mtarjeta_visa_consumo_delta6"
# [221] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [223] "mtarjeta_master_consumo_delta3"     "mtarjeta_master_consumo_delta6"
# [225] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [227] "mprestamos_personales_delta3"       "mprestamos_personales_delta6"
# [229] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [231] "cpayroll_trx_delta3"                "cpayroll_trx_delta6"
# [233] "mpayroll_delta1"                    "mpayroll_delta2"
# [235] "mpayroll_delta3"                    "mpayroll_delta6"
# [237] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [239] "ccomisiones_mantenimiento_delta3"   "ccomisiones_mantenimiento_delta6"
# [241] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [243] "ccallcenter_transacciones_delta3"   "ccallcenter_transacciones_delta6"
# [245] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [247] "chomebanking_transacciones_delta3"  "chomebanking_transacciones_delta6"
# [249] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [251] "ctrx_quarter_delta3"                "ctrx_quarter_delta6"
# [253] "Master_status_delta1"               "Master_status_delta2"
# [255] "Master_status_delta3"               "Master_status_delta6"
# [257] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [259] "Master_fechaalta_delta3"            "Master_fechaalta_delta6"
# [261] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [263] "Master_mpagominimo_delta3"          "Master_mpagominimo_delta6"
# [265] "Visa_status_delta1"                 "Visa_status_delta2"
# [267] "Visa_status_delta3"                 "Visa_status_delta6"
# [269] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [271] "Visa_fechaalta_delta3"              "Visa_fechaalta_delta6"
# [273] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [275] "Visa_mpagominimo_delta3"            "Visa_mpagominimo_delta6"
# [277] "coeficiente_de_ajuste_delta1"       "coeficiente_de_ajuste_delta2"
# [279] "coeficiente_de_ajuste_delta3"       "coeficiente_de_ajuste_delta6"
# [281] "kmes_delta1"                        "kmes_delta2"
# [283] "kmes_delta3"                        "kmes_delta6"
# [285] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"
# [287] "mpayroll_sobre_edad_delta3"         "mpayroll_sobre_edad_delta6"
# [289] "ratio_profitability_score"          "balance_trend_score"
# [291] "activity_behavior_score"

# %% [markdown]
# **FIN MODIFICACIÓN EXPERIMENTO #16**

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16551

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
PARAM$hipeparametertuning$num_interations <- 50        # AUMENTO LA CANTIDAD DE ITERACIONES DE 10 A 50.

# parametros fijos del LightGBM                        # EXPERIMENTO #14. Utilizar boosting type = GBDT. Es el valor por defecto.
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",                                       # EXPERIMENTO #12. Emplear métrica AUC para la BO.
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  max_bin= 31,
  learning_rate= 0.03,
  feature_fraction= 0.5,
  num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  early_stopping_rounds= 200
)

PARAM$hipeparametertuning$hs <- makeParamSet(
 # makeNumericParam("learning_rate", lower = 0.01, upper = 0.1),
  makeIntegerParam("num_leaves", lower = 2L, upper = 256L),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L)
)

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {                                       # EXPERIMENTO #18. Recomienda usar una BO simple con una sola semilla (no robusta con 5 semillas)

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Warning message in mboContinue("HT.RDATA"):
# “Tuning ended with term.iter. No need to continue. Simply returning stored result.”

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_data_in_leaf num_iterations
#         <int>            <int>          <int>
# 1:        234              124            687

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c( 202107,
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 240562

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202109)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Kaggle Competition Submit

# %% [markdown]
# Genero las salidas y hago los submits a Kaggle
# <br>El notebook esta preparado para la Modalidad Gerencial, los analistas deben hacer cambios.
# <br> Los analistas deben cambiar **competencia** a SU competencia  "data-mining-analista-jr-2025-a"   o  la original "data-mining-analista-sr-2025-a"  para los Senior
# <br> Los cortes  dependen de la cantidad de registros, multiplicar por 2 para los Analistas Jr y por 10 para los Analista Sr
#
# Los Analista Sr luego de meditar cuidadosamente reducirán la cantidad de cortes

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

PARAM$kaggle$competencia <- "labo-i-2025-virtual-gerencial"
PARAM$kaggle$cortes <- seq(800, 1300, by = 50)

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Dec 01 12:39:27 AM 2025"
